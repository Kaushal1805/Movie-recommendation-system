# %%
import numpy as pd
import pandas as pd
movies = pd.read_csv('tmdb_5000_movies[1].csv')
credits = pd.read_csv('tmdb_5000_credits[1].csv')

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
movies.shape
# Out:
# (1494, 24)

# %%
movies = movies.merge(credits, on='title')

# %%
movies.head(1)

# %%
movies[['movie_id','title','overview','genres','keywords','cast','crew']]
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4804      9367                               El Mariachi
# 4805     72766                                 Newlyweds
# 4806    231617                 Signed, Sealed, Delivered
# 4807    126186                          Shanghai Calling
# 4808     25975                         My Date with Drew
#
#                                                overview  \
# 0     In the 22nd century, a paraplegic Marine is di...
# 1     Captain Barbossa, long believed to be dead, ha...
# 2     A cryptic message from Bond’s past sends him o...
# ...

# %%
movies.dropna(inplace=True)

# %% [markdown]
# movies.isnull().sum()

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name']) 
    return L

# %%
import ast

def convert(text):
    L = []
    for i in ast.literal_eval(text):
        L.append(i['name'])
    return L

# safety for NaN values
movies['genres'] = movies['genres'].fillna('[]')

movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
import ast

def convert3(text):
    L = []
    counter = 0
    for i in ast.literal_eval(text):
        if counter < 3:
            L.append(i['name'])
            counter += 1
        else:
            break
    return L

# %%
movies['cast']=movies['cast'].apply(convert3)

# %%
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
movies['cast'] = movies['cast'].apply(lambda x:x[0:3])

# %%
import ast

def fetch_director(text):
    # agar already list hai → return as it is
    if isinstance(text, list):
        return text
    
    L = []
    try:
        for i in ast.literal_eval(text):
            if i.get('job') == 'Director':
                L.append(i.get('name'))
                break
    except:
        return []
    
    return L

# %%
movies['crew'] = movies['crew'].fillna('[]')
movies['crew'] = movies['crew'].apply(fetch_director)

# %%
movies.head()
# Out:
#       budget                                         genres  \
# 0  237000000  [Action, Adventure, Fantasy, Science Fiction]
# 1  300000000                   [Adventure, Fantasy, Action]
# 2  245000000                     [Action, Adventure, Crime]
# 3  250000000               [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, Science Fiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [culture clash, future, space war, space colon...                en
# 1  [ocean, drug abuse, exotic island, east india ...                en
# ...

# %%
def collapse(L):
    L1 = []
    for i in L:
        L1.append(i.replace(" ",""))
    return L1

# %%
movies['genres']=movies['genres'].apply(lambda x:[i.replace(" ","")for i in x])
movies['keywords']=movies['keywords'].apply(lambda x:[i.replace(" ","")for i in x])
movies['cast']=movies['cast'].apply(lambda x:[i.replace(" ","")for i in x])
movies['crew']=movies['crew'].apply(lambda x:[i.replace(" ","")for i in x])

# %%
movies.head()
# Out:
#       budget                                        genres  \
# 0  237000000  [Action, Adventure, Fantasy, ScienceFiction]
# 1  300000000                  [Adventure, Fantasy, Action]
# 2  245000000                    [Action, Adventure, Crime]
# 3  250000000              [Action, Crime, Drama, Thriller]
# 4  260000000           [Action, Adventure, ScienceFiction]
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [cultureclash, future, spacewar, spacecolony, ...                en
# 1  [ocean, drugabuse, exoticisland, eastindiatrad...                en
# ...

# %%
# pehle sabko string bana do
movies['overview'] = movies['overview'].astype(str)

# ab split lagao (sirf ek baar)
movies['overview'] = movies['overview'].apply(lambda x: x.split())

# %%
# overview (agar string ho to split)
movies['overview'] = movies['overview'].apply(
    lambda x: x.split() if isinstance(x, str) else x
)

# genres, keywords, cast, crew → agar string ho to list me convert
movies['genres']   = movies['genres'].apply(lambda x: x if isinstance(x, list) else x.split())
movies['keywords'] = movies['keywords'].apply(lambda x: x if isinstance(x, list) else x.split())
movies['cast']     = movies['cast'].apply(lambda x: x if isinstance(x, list) else x.split())
movies['crew']     = movies['crew'].apply(lambda x: x if isinstance(x, list) else x.split())

# %%
movies['tags'] = (
    movies['overview'] +
    movies['genres'] +
    movies['keywords'] +
    movies['cast'] +
    movies['crew']
)

# %%
movies['tags'] = movies['tags'].apply(lambda x: " ".join(x))
movies['tags'] = movies['tags'].apply(lambda x: x.lower())

# %%
import nltk

# %%
# !pip install nltk

# %%
from nltk.stem.porter import PorterStemmer
ps=PorterStemmer()

# %%
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

# %%
new_df['tags']=new_df['tags'].apply(stem)

# %%
new_df = movies[['movie_id', 'title', 'tags']]
new_df.head(5000)
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4779      2292                                    Clerks
# 4787    255266                                 Dry Spell
# 4797    157185                               Tin Can Man
# 4802     14337                                    Primer
# 4807    126186                          Shanghai Calling
#
#                                                    tags
# 0     in the 22nd century, a paraplegic marine is di...
# 1     captain barbossa, long believed to be dead, ha...
# 2     a cryptic message from bond’s past sends him o...
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')

# %%
vector = cv.fit_transform(new_df['tags']).toarray()

# %%
vector.shape
# Out:
# (1494, 5000)

# %%
cv.get_feature_names_out()
# Out:
# array(['00', '000', '007', ..., 'zoo', 'zooey', 'zooeydeschanel'],
#       shape=(5000,), dtype=object)

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(vector).shape
# Out:
# (1494, 1494)

# %%
similarity = cosine_similarity(vector)

# %%
similarity
# Out:
# array([[1.        , 0.08035074, 0.05437272, ..., 0.        , 0.05437272,
#         0.02469324],
#        [0.08035074, 1.        , 0.05970814, ..., 0.04428074, 0.        ,
#         0.        ],
#        [0.05437272, 0.05970814, 1.        , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.        , 0.04428074, 0.        , ..., 1.        , 0.        ,
#         0.04082483],
#        [0.05437272, 0.        , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.02469324, 0.        , 0.        , ..., 0.04082483, 0.        ,
#         1.        ]], shape=(1494, 1494))

# %%
def recommend(movie):
    # movie exist karti hai ya nahi
    if movie not in new_df['title'].values:
        print("❌ Movie not found")
        return

    movie_index = new_df[new_df['title'] == movie].index[0]

    distances = similarity[movie_index]

    movie_list = sorted(
        list(enumerate(distances)),
        reverse=True,
        key=lambda x: x[1]
    )[1:6]

    print("🎬 Recommended movies:\n")
    for i in movie_list:
        print(new_df.iloc[i[0]]['title'])

# %%
recommend('Avatar')
# Out:
# 🎬 Recommended movies:
#
# Ender's Game
# Aliens vs Predator: Requiem
# Battle: Los Angeles
# Apollo 18
# Jupiter Ascending

# %%
import pickle

# %%
pickle.dump(new_df,open('movie_list.pkl','wb'))
pickle.dump(similarity,open('similarity.pkl','wb'))
